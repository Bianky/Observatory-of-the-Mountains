# %%
import sys
sys.executable

import numpy as np
import pandas as pd
import geopandas as gpd
from inequality.theil import Theil
import libpysal
import matplotlib.pyplot as plt
import seaborn as sns
import inequality

# %%
import os
os.getcwd()

data_pth = "../../../../frontend/data/"

# %%
df = pd.read_json(f"{data_pth}w_domestic.json")
df.head()
# Out:
#            county      2015      2016      2017      2018      2019      2020  \
# 0        Alt Camp   36.9273   37.6630   37.8020   37.2609   37.3736   38.9238
# 1     Alt Empordà   57.5981   59.0324   58.8211   58.0512   59.3736   57.5913
# 2     Alt Penedès   39.2388   39.7713   39.9355   38.6406   39.6307   42.2577
# 3      Alt Urgell   45.1897   46.1018   46.3244   45.6042   48.1885   49.3747
# 4  Alta Ribagorça  102.0597  102.1981  114.9203  130.7366  128.6165  120.8366
#
#        2021      2022      2023      2024     region
# 0   38.0619   37.0158   37.1386   34.2481  Catalunya
# 1   59.7919   59.2972   54.6523   50.6461  Catalunya
# 2   41.7828   40.8676   38.7907   36.9335  Catalunya
# 3   51.4937   49.6289   47.9096   47.6666   Pyrenees
# 4  116.8568  118.5195  116.0737  115.5446   Pyrenees

# %%
gdf = gpd.read_file(f"{data_pth}geometry_counties_all.geojson")

# %%
ax = gdf.plot(edgecolor = "grey")
ax.set_axis_off()

# %%
gdf.head()
# Out:
#            county                                           geometry
# 0        Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 1     Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...
# 2     Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...
# 3      Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...
# 4  Alta Ribagorça  MULTIPOLYGON (((0.8795 42.6314, 0.87967 42.631...

# %%
w_dom = gdf.merge(df, on="county", how="left")
w_dom.head()
# Out:
#            county                                           geometry  \
# 0        Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 1     Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...
# 2     Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...
# 3      Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...
# 4  Alta Ribagorça  MULTIPOLYGON (((0.8795 42.6314, 0.87967 42.631...
#
#        2015      2016      2017      2018      2019      2020      2021  \
# 0   36.9273   37.6630   37.8020   37.2609   37.3736   38.9238   38.0619
# 1   57.5981   59.0324   58.8211   58.0512   59.3736   57.5913   59.7919
# 2   39.2388   39.7713   39.9355   38.6406   39.6307   42.2577   41.7828
# 3   45.1897   46.1018   46.3244   45.6042   48.1885   49.3747   51.4937
# 4  102.0597  102.1981  114.9203  130.7366  128.6165  120.8366  116.8568
#
#        2022      2023      2024     region
# 0   37.0158   37.1386   34.2481  Catalunya
# 1   59.2972   54.6523   50.6461  Catalunya
# 2   40.8676   38.7907   36.9335  Catalunya
# 3   49.6289   47.9096   47.6666   Pyrenees
# 4  118.5195  116.0737  115.5446   Pyrenees

# %%
ax = w_dom.plot(
    column="2023", k=5, scheme="Quantiles", edgecolor="grey", legend=True
)
ax.set_axis_off()
ax.set_title("Domestic water consumption (m³/inhabitant) 2023");

# %%
theil_2015 = inequality.theil.Theil(w_dom["2015"].dropna())
theil_2015.T
# Out:
# 0.05204420155514644

# %%
inequality.theil.TheilD
# Out:
# inequality.theil.TheilD

# %%
regimes = w_dom["region"].astype(str)

# %%
ax = w_dom.plot(column="region", categorical=True, edgecolor="grey")
ax.set_title("Regions")
ax.set_axis_off()

# %%
np.random.seed(12345)
ts = inequality.theil.TheilD(w_dom["2015"].dropna(), regimes)

# %%
ts.T
# Out:
# 0.05204420155514644

# %%
ts.bg
# Out:
# array([-0.00490351])

# %%
ts.wg
# Out:
# array([0.05694771])

# %%
ts.bg[0] / ts.T
# Out:
# np.float64(-0.09421817722716166)

# %%
np.random.seed(10)

# %%
mask = w_dom["2015"].notna()

values =w_dom.loc[mask, "2015"]
regs   = w_dom.loc[mask, "region"].astype(str)

ts = inequality.theil.TheilDSim(values, regs, permutations=999)

# %%
ts.bg_pvalue
# Out:
# array([0.001])

# %%
kdeplot = sns.kdeplot(ts.bg, fill=False, legend=False)
x_vals = kdeplot.lines[0].get_xdata()
y_vals = kdeplot.lines[0].get_ydata()
plt.fill_between(x_vals, y_vals, where=(x_vals > ts.bg[0]), color="red")
plt.xlabel("Between Regions Inequality 2015");

# %%
years = range(2015, 2024)
np.random.seed(12345)

ts = [inequality.theil.Theil(w_dom[f"{year}"]).T for year in years]

regimes = w_dom["region"]
tsd = [
    inequality.theil.TheilDSim(
        w_dom[f"{year}"].dropna(),
        regimes[w_dom[f"{year}"].notna()],  
        permutations=999
    )
    for year in years
]
p = np.array([(tsdi.bg_pvalue[0], tsdi.T, tsdi.results[0].bg[0]) for tsdi in tsd])

# %%
rdf = pd.DataFrame(data=p, columns=["p-value", "Theil", "BG"])
rdf["BGshare"] = rdf.BG / rdf.Theil
rdf["Year"] = years

rdf.tail()
# Out:
#    p-value     Theil        BG   BGshare  Year
# 0    0.002  0.052044  0.016259  0.312400  2015
# 1    0.003  0.054602  0.017018  0.311677  2016
# 2    0.002  0.058818  0.019306  0.328234  2017
# 3    0.002  0.067855  0.023520  0.346628  2018
# 4    0.003  0.071821  0.025166  0.350395  2019

# %%
significant_points = rdf[rdf["p-value"] <= 0.05]
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.plot(rdf["Year"], rdf["Theil"], marker="o", label="Theil", color="blue")
ax1.plot(rdf["Year"], rdf["BG"], marker="s", label="BG", color="green")
ax1.set_xlabel("Year")
ax1.set_ylabel("Theil / BG Value")
ax1.set_title("Time Series of Theil, BG, and BGshare (2015-2024)")
ax2 = ax1.twinx()
ax2.plot(rdf["Year"], rdf["BGshare"], marker="D", label="BGshare", color="orange")
ax2.scatter(
    significant_points["Year"],
    significant_points["BGshare"],
    color="red",
    label="Significant BGshare (p ≤ 0.05)",
    zorder=3,
)

ax2.set_ylabel("BGshare Value")
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
ax1.grid(True)
plt.show()
