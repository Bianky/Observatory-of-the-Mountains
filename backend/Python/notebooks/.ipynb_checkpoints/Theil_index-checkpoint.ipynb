# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\Bianka\\miniforge3\\envs\\my_jupyter_env\\python.exe'

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from inequality.theil import Theil
import libpysal
import matplotlib.pyplot as plt
import seaborn as sns
import inequality

# %%
# %load_ext watermark

# %watermark -w 
# %watermark -iv
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Watermark: 2.5.0
#
# libpysal  : 4.13.0
# pandas    : 2.3.3
# inequality: 1.1.2
# geopandas : 1.1.1
# seaborn   : 0.13.2
# matplotlib: 3.10.8
# numpy     : 2.3.5
# sys       : 3.12.12 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 20:05:38) [MSC v.1929 64 bit (AMD64)]
#
# Last updated:
