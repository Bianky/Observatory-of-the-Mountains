# %%
import sys
sys.executable

import numpy as np
import pandas as pd
import geopandas as gpd
from inequality.theil import Theil
import libpysal
import matplotlib.pyplot as plt
import seaborn as sns
import inequality

# %%
import os
os.getcwd()

data_pth = "../../../frontend/data/"

# %%
df = pd.read_json(f"{data_pth}ret.json")
df.head()
# Out:
#            county      2015      2016       2017       2018       2019  \
# 0     Alt Empordà  787758.0  966582.0  1095365.0  1170261.0  1204777.0
# 1     Alt Penedès  518983.0  602510.0   713556.0   733735.0   798828.0
# 2      Alt Urgell  142253.0  159864.0   230242.0   295388.0   292035.0
# 3  Alta Ribagorça   40349.0   67073.0    70048.0    71021.0    71354.0
# 4           Anoia  367264.0  450503.0   502701.0   530262.0   563957.0
#
#         2020       2021       2022     2023     2024     region
# 0  1228239.0  1166591.0  1170533.0  1173432  1272751  Catalunya
# 1   833228.0   832108.0   886158.0   905069   889565  Catalunya
# 2   293771.0   293548.0   291029.0   291817   291697   Pyrenees
# 3    70358.0    70750.0    70433.0    70438    64149   Pyrenees
# 4   591950.0   619600.0   664023.0   678887   991064  Catalunya

# %%
gdf = gpd.read_file(f"{data_pth}geometry_counties_all.geojson")

# %%
ax = gdf.plot(edgecolor = "grey")
ax.set_axis_off()

# %%
gdf.head()
# Out:
#            county                                           geometry
# 0        Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 1     Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...
# 2     Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...
# 3      Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...
# 4  Alta Ribagorça  MULTIPOLYGON (((0.8795 42.6314, 0.87967 42.631...

# %%
ret = gdf.merge(df, on="county", how="left")
ret.head()
# Out:
#            county                                           geometry  \
# 0        Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 1     Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...
# 2     Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...
# 3      Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...
# 4  Alta Ribagorça  MULTIPOLYGON (((0.8795 42.6314, 0.87967 42.631...
#
#        2015      2016       2017       2018       2019       2020       2021  \
# 0       NaN       NaN        NaN        NaN        NaN        NaN        NaN
# 1  787758.0  966582.0  1095365.0  1170261.0  1204777.0  1228239.0  1166591.0
# 2  518983.0  602510.0   713556.0   733735.0   798828.0   833228.0   832108.0
# 3  142253.0  159864.0   230242.0   295388.0   292035.0   293771.0   293548.0
# 4   40349.0   67073.0    70048.0    71021.0    71354.0    70358.0    70750.0
#
#         2022       2023       2024     region
# 0        NaN        NaN        NaN        NaN
# 1  1170533.0  1173432.0  1272751.0  Catalunya
# 2   886158.0   905069.0   889565.0  Catalunya
# 3   291029.0   291817.0   291697.0   Pyrenees
# 4    70433.0    70438.0    64149.0   Pyrenees

# %%
ax = ret.plot(
    column="2015", k=5, scheme="Quantiles", edgecolor="grey", legend=True
)
ax.set_axis_off()
ax.set_title("Rural estate tax 2015");

# %%
theil_2015 = inequality.theil.Theil(ret["2015"].dropna())
theil_2015.T
# Out:
# 0.47678459839418097

# %%
inequality.theil.TheilD
# Out:
# inequality.theil.TheilD

# %%
regimes = ret["region"].astype(str)

# %%
ax = ret.plot(column="region", categorical=True, edgecolor="grey")
ax.set_title("Regions")
ax.set_axis_off()

# %%
np.random.seed(12345)
ts = inequality.theil.TheilD(ret["2015"].dropna(), regimes)

# %%
ts.T
# Out:
# 0.47678459839418097

# %%
ts.bg
# Out:
# array([0.0721669])

# %%
ts.wg
# Out:
# array([0.40461769])

# %%
ts.bg[0] / ts.T
# Out:
# np.float64(0.15136165292466647)

# %%
np.random.seed(10)

# %%
mask = ret["2015"].notna()

values =ret.loc[mask, "2015"]
regs   = ret.loc[mask, "region"].astype(str)

ts = inequality.theil.TheilDSim(values, regs, permutations=999)

# %%
ts.bg_pvalue
# Out:
# array([0.006])

# %%
kdeplot = sns.kdeplot(ts.bg, fill=False, legend=False)
x_vals = kdeplot.lines[0].get_xdata()
y_vals = kdeplot.lines[0].get_ydata()
plt.fill_between(x_vals, y_vals, where=(x_vals > ts.bg[0]), color="red")
plt.xlabel("Between Regions Inequality 2015");

# %%
years = range(1986, 2023)
np.random.seed(12345)

ts = [inequality.theil.Theil(ret[f"{year}"]).T for year in years]

regimes = r["region"]
tsd = [
    inequality.theil.TheilDSim(
        gr[f"{year}"].dropna(),
        regimes[gr[f"{year}"].notna()],  
        permutations=999
    )
    for year in years
]
p = np.array([(tsdi.bg_pvalue[0], tsdi.T, tsdi.results[0].bg[0]) for tsdi in tsd])

# %%
rdf = pd.DataFrame(data=p, columns=["p-value", "Theil", "BG"])
rdf["BGshare"] = rdf.BG / rdf.Theil
rdf["Year"] = years

rdf.head()
# Out:
#    p-value     Theil        BG   BGshare  Year
# 0    0.001  0.023438  0.007372  0.314516  2015
# 1    0.001  0.025003  0.008275  0.330956  2016
# 2    0.001  0.026573  0.008211  0.308990  2017
# 3    0.001  0.028007  0.009642  0.344289  2018
# 4    0.001  0.027677  0.008976  0.324323  2019

# %%
significant_points = rdf[rdf["p-value"] <= 0.05]
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.plot(rdf["Year"], rdf["Theil"], marker="o", label="Theil", color="blue")
ax1.plot(rdf["Year"], rdf["BG"], marker="s", label="BG", color="green")
ax1.set_xlabel("Year")
ax1.set_ylabel("Theil / BG Value")
ax1.set_title("Time Series of Theil, BG, and BGshare (2013-2022)")
ax2 = ax1.twinx()
ax2.plot(rdf["Year"], rdf["BGshare"], marker="D", label="BGshare", color="orange")
ax2.scatter(
    significant_points["Year"],
    significant_points["BGshare"],
    color="red",
    label="Significant BGshare (p ≤ 0.05)",
    zorder=3,
)

ax2.set_ylabel("BGshare Value")
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
ax1.grid(True)
plt.show()
