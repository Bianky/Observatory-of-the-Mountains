# %%
import sys
sys.executable

import numpy as np
import pandas as pd
import geopandas as gpd
from inequality.theil import Theil
import libpysal
import matplotlib.pyplot as plt
import seaborn as sns
import inequality

# %%
import os
os.getcwd()

data_pth = "../../../frontend/data/"

# %%
df = pd.read_json(f"{data_pth}gdp.json")
df.head()
# Out:
#            county  GDP_percapita_eur  year
# 0        Alt Camp              28719  2013
# 1     Alt Empordà              20275  2013
# 2     Alt Penedès              26753  2013
# 3      Alt Urgell              20382  2013
# 4  Alta Ribagorça              22801  2013

# %%
gdf = gpd.read_file(f"{data_pth}geometry_counties_all.geojson")

# %%
ax = gdf.plot(edgecolor = "grey")
ax.set_axis_off()

# %%
gdf.head()
# Out:
#            county                                           geometry
# 0        Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 1     Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...
# 2     Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...
# 3      Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...
# 4  Alta Ribagorça  MULTIPOLYGON (((0.8795 42.6314, 0.87967 42.631...

# %%
gdp = gdf.merge(df, on="county", how="left")
gdp.head()
# Out:
#      county                                           geometry  \
# 0  Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 1  Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 2  Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 3  Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 4  Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
#
#    GDP_percapita_eur    year
# 0            28719.0  2013.0
# 1            31021.0  2014.0
# 2            29584.0  2015.0
# 3            31598.0  2016.0
# 4            33349.0  2017.0

# %%
ax = gdp.plot(
    column="2023", k=5, scheme="Quantiles", edgecolor="grey", legend=True
)
ax.set_axis_off()
ax.set_title("GDP pc 2023");
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2023'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 ax = gdp.plot(
#       2     column="2023", k=5, scheme="Quantiles", edgecolor="grey", legend=True
#       3 )
#       4 ax.set_axis_off()
#       5 ax.set_title("Real investment budget 2023");
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\geopandas\plotting.py:962, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     960 kind = kwargs.pop("kind", "geo")
#     961 if kind == "geo":
# --> 962     return plot_dataframe(data, *args, **kwargs)
#     963 if kind in self._pandas_kinds:
#     964     # Access pandas plots
#     965     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\geopandas\plotting.py:715, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, autolim, **style_kwds)
#     713             values = values.reindex(df.index)
#     714 else:
# --> 715     values = df[column]
#     717 if isinstance(values.dtype, CategoricalDtype):
#     718     if categories is not None:
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\geopandas\geodataframe.py:1896, in GeoDataFrame.__getitem__(self, key)
#    1890 def __getitem__(self, key):
#    1891     """
#    1892     If the result is a column containing only 'geometry', return a
#    1893     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1894     return a GeoDataFrame.
#    1895     """
# -> 1896     result = super().__getitem__(key)
#    1897     # Custom logic to avoid waiting for pandas GH51895
#    1898     # result is not geometry dtype for multi-indexes
#    1899     if (
#    1900         pd.api.types.is_scalar(key)
#    1901         and key == ""
#    (...)   1904         and not is_geometry_type(result)
#    1905     ):
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '2023'

# %%
theil_2023 = inequality.theil.Theil(rib["2023"].dropna())
theil_2023.T
# Out:
# 1.0836491706216904

# %%
inequality.theil.TheilD
# Out:
# inequality.theil.TheilD

# %%
regimes = rib["region"].astype(str)
regimes
# Out:
# 0     Catalunya
# 1     Catalunya
# 2     Catalunya
# 3      Pyrenees
# 4      Pyrenees
# 5     Catalunya
# 6     Catalunya
# 7     Catalunya
# 8     Catalunya
# 9     Catalunya
# 10    Catalunya
# 11    Catalunya
# 12     Pyrenees
# 13     Pyrenees
# 14    Catalunya
# 15    Catalunya
# 16    Catalunya
# 17    Catalunya
# 18    Catalunya
# 19    Catalunya
# 20    Catalunya
# 21    Catalunya
# 22    Catalunya
# 23     Pyrenees
# 24     Pyrenees
# 25    Catalunya
# 26    Catalunya
# 27    Catalunya
# 28    Catalunya
# 29     Pyrenees
# 30    Catalunya
# 31    Catalunya
# 32    Catalunya
# 33     Pyrenees
# 34    Catalunya
# 35    Catalunya
# 36    Catalunya
# 37     Pyrenees
# 38    Catalunya
# 39    Catalunya
# 40    Catalunya
# 41          nan
# 42    Catalunya
# Name: region, dtype: object

# %%
ax = rib.plot(column="region", categorical=True, edgecolor="grey")
ax.set_title("Regions")
ax.set_axis_off()

# %%
np.random.seed(12345)
ts = inequality.theil.TheilD(rib["2023"].dropna(), regimes)

# %%
ts.T
# Out:
# 1.0836491706216904

# %%
ts.bg
# Out:
# array([0.12577844])

# %%
ts.wg
# Out:
# array([0.95787073])

# %%
ts.bg[0] / ts.T
# Out:
# np.float64(0.11606933995213246)

# %%
np.random.seed(10)

# %%
ts = inequality.theil.TheilDSim(rib["2023"], regimes, permutations=999)

# %%
ts.bg_pvalue
# Out:
# array([0.001])

# %%
kdeplot = sns.kdeplot(ts.bg, fill=False, legend=False)
x_vals = kdeplot.lines[0].get_xdata()
y_vals = kdeplot.lines[0].get_ydata()
plt.fill_between(x_vals, y_vals, where=(x_vals > ts.bg[0]), color="red")
plt.xlabel("Between Regions Inequality 2023");
# Out:
# C:\Users\Bianka\AppData\Local\Temp\ipykernel_11760\3586122174.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot = sns.kdeplot(ts.bg, fill=False, legend=False)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[70], line 2
#       1 kdeplot = sns.kdeplot(ts.bg, fill=False, legend=False)
# ----> 2 x_vals = kdeplot.lines[0].get_xdata()
#       3 y_vals = kdeplot.lines[0].get_ydata()
#       4 plt.fill_between(x_vals, y_vals, where=(x_vals > ts.bg[0]), color="red")
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\matplotlib\axes\_base.py:1514, in _AxesBase.ArtistList.__getitem__(self, key)
#    1513 def __getitem__(self, key):
# -> 1514     return [artist
#    1515             for artist in self._axes._children
#    1516             if self._type_check(artist)][key]
#
# IndexError: list index out of range

# %%
years = range(2015, 2024)
np.random.seed(12345)

ts = [inequality.theil.Theil(income[f"{year}"].dropna()).T for year in years]

regimes = income["region"]
tsd = [
    inequality.theil.TheilDSim(
        income[f"{year}"].dropna(),
        regimes[income[f"{year}"].notna()],  
        permutations=999
    )
    for year in years
]
p = np.array([(tsdi.bg_pvalue[0], tsdi.T, tsdi.results[0].bg[0]) for tsdi in tsd])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2016'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 4
#       1 years = range(2015, 2024)
#       2 np.random.seed(12345)
# ----> 4 ts = [inequality.theil.Theil(income[f"{year}"].dropna()).T for year in years]
#       6 regimes = income["region"]
#       7 tsd = [
#       8     inequality.theil.TheilDSim(
#       9         income[f"{year}"].dropna(),
#    (...)     13     for year in years
#      14 ]
#
# Cell In[71], line 4, in <listcomp>(.0)
#       1 years = range(2015, 2024)
#       2 np.random.seed(12345)
# ----> 4 ts = [inequality.theil.Theil(income[f"{year}"].dropna()).T for year in years]
#       6 regimes = income["region"]
#       7 tsd = [
#       8     inequality.theil.TheilDSim(
#       9         income[f"{year}"].dropna(),
#    (...)     13     for year in years
#      14 ]
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\geopandas\geodataframe.py:1896, in GeoDataFrame.__getitem__(self, key)
#    1890 def __getitem__(self, key):
#    1891     """
#    1892     If the result is a column containing only 'geometry', return a
#    1893     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1894     return a GeoDataFrame.
#    1895     """
# -> 1896     result = super().__getitem__(key)
#    1897     # Custom logic to avoid waiting for pandas GH51895
#    1898     # result is not geometry dtype for multi-indexes
#    1899     if (
#    1900         pd.api.types.is_scalar(key)
#    1901         and key == ""
#    (...)   1904         and not is_geometry_type(result)
#    1905     ):
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '2016'

# %%
rdf = pd.DataFrame(data=p, columns=["p-value", "Theil", "BG"])
rdf["BGshare"] = rdf.BG / rdf.Theil
rdf["Year"] = years

rdf.head()
# Out:
#    p-value     Theil        BG   BGshare  Year
# 0    0.106  0.008915  0.000548  0.061428  2015
# 1    0.130  0.008866  0.000492  0.055459  2016
# 2    0.110  0.008313  0.000552  0.066346  2017
# 3    0.096  0.008506  0.000544  0.063914  2018
# 4    0.161  0.008604  0.000424  0.049292  2019

# %%
significant_points = rdf[rdf["p-value"] <= 0.05]
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.plot(rdf["Year"], rdf["Theil"], marker="o", label="Theil", color="blue")
ax1.plot(rdf["Year"], rdf["BG"], marker="s", label="BG", color="green")
ax1.set_xlabel("Year")
ax1.set_ylabel("Theil / BG Value")
ax1.set_title("Time Series of Theil, BG, and BGshare (2015-2023)")
ax2 = ax1.twinx()
ax2.plot(rdf["Year"], rdf["BGshare"], marker="D", label="BGshare", color="orange")
ax2.scatter(
    significant_points["Year"],
    significant_points["BGshare"],
    color="red",
    label="Significant BGshare (p ≤ 0.05)",
    zorder=3,
)

ax2.set_ylabel("BGshare Value")
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
ax1.grid(True)
plt.show()
