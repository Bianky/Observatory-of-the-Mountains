# %%
import sys
sys.executable

import numpy as np
import pandas as pd
import geopandas as gpd
from inequality.theil import Theil
import libpysal
import matplotlib.pyplot as plt
import seaborn as sns
import inequality

# %%
import os
os.getcwd()

data_pth = "../../../frontend/data/"

# %%
df = pd.read_json(f"{data_pth}old.json")
df.head()
# Out:
#            county   2018   2019   2020   2021   2022   2023     region
# 0     Alt Empordà  15.32  15.49  16.28  16.71  17.26  17.64  Catalunya
# 1     Alt Penedès  18.49  18.61  19.63  20.02  20.61  21.15  Catalunya
# 2      Alt Urgell  18.89  19.09  20.03  20.96  21.68  22.28   Pyrenees
# 3  Alta Ribagorça  23.65  23.16  23.73  24.43  25.02  25.89   Pyrenees
# 4           Anoia  15.68  15.87  16.69  16.80  17.31  17.78  Catalunya

# %%
gdf = gpd.read_file(f"{data_pth}geometry_counties_all.geojson")

# %%
ax = gdf.plot(edgecolor = "grey")
ax.set_axis_off()

# %%
gdf.head()
# Out:
#            county                                           geometry
# 0        Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 1     Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...
# 2     Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...
# 3      Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...
# 4  Alta Ribagorça  MULTIPOLYGON (((0.8795 42.6314, 0.87967 42.631...

# %%
house = gdf.merge(df, on="county", how="left")
house.head()
# Out:
#            county                                           geometry   2018  \
# 0        Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...    NaN
# 1     Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...  15.32
# 2     Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...  18.49
# 3      Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...  18.89
# 4  Alta Ribagorça  MULTIPOLYGON (((0.8795 42.6314, 0.87967 42.631...  23.65
#
#     2019   2020   2021   2022   2023     region
# 0  15.75  16.74  17.14  17.73  18.09  Catalunya
# 1  15.49  16.28  16.71  17.26  17.64  Catalunya
# 2  18.61  19.63  20.02  20.61  21.15  Catalunya
# 3  19.09  20.03  20.96  21.68  22.28   Pyrenees
# 4  23.16  23.73  24.43  25.02  25.89   Pyrenees

# %%
ax = house.plot(
    column="2018", k=5, scheme="Quantiles", edgecolor="grey", legend=True
)
ax.set_axis_off()
ax.set_title("Average selling price for a second-hand house (€/m²) 2018");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ax = house.plot(
#       2     column="2018", k=5, scheme="Quantiles", edgecolor="grey", legend=True
#       3 )
#       4 ax.set_axis_off()
#       5 ax.set_title("Average selling price for a second-hand house (€/m²) 2018");
#
# NameError: name 'house' is not defined

# %%
theil_2015 = inequality.theil.Theil(house["2018"].dropna())
theil_2015.T
# Out:
# 0.01915666911826411

# %%
inequality.theil.TheilD
# Out:
# inequality.theil.TheilD

# %%
regimes = house["region"].astype(str)

# %%
ax = house.plot(column="region", categorical=True, edgecolor="grey")
ax.set_title("Regions")
ax.set_axis_off()

# %%
np.random.seed(12345)
ts = inequality.theil.TheilD(house["2018"].dropna(), regimes)

# %%
ts.T
# Out:
# 0.01915666911826411

# %%
ts.bg
# Out:
# array([-0.02259734])

# %%
ts.wg
# Out:
# array([0.04175401])

# %%
ts.bg[0] / ts.T
# Out:
# np.float64(-1.1796067975065767)

# %%
np.random.seed(10)

# %%
mask = house["2018"].notna()

values =house.loc[mask, "2018"]
regs   = house.loc[mask, "region"].astype(str)

ts = inequality.theil.TheilDSim(values, regs, permutations=999)

# %%
ts.bg_pvalue
# Out:
# array([0.188])

# %%
kdeplot = sns.kdeplot(ts.bg, fill=False, legend=False)
x_vals = kdeplot.lines[0].get_xdata()
y_vals = kdeplot.lines[0].get_ydata()
plt.fill_between(x_vals, y_vals, where=(x_vals > ts.bg[0]), color="red")
plt.xlabel("Between Regions Inequality 2015");

# %%
years = range(2015, 2024)
np.random.seed(12345)

ts = [inequality.theil.Theil(house[f"{year}"]).T for year in years]

regimes = house["region"]
tsd = [
    inequality.theil.TheilDSim(
        house[f"{year}"].dropna(),
        regimes[house[f"{year}"].notna()],  
        permutations=999
    )
    for year in years
]
p = np.array([(tsdi.bg_pvalue[0], tsdi.T, tsdi.results[0].bg[0]) for tsdi in tsd])

# %%
rdf = pd.DataFrame(data=p, columns=["p-value", "Theil", "BG"])
rdf["BGshare"] = rdf.BG / rdf.Theil
rdf["Year"] = years

rdf.head()
# Out:
#    p-value     Theil        BG   BGshare  Year
# 0    0.192  0.019157  0.000880  0.045947  2018
# 1    0.157  0.019448  0.001020  0.052422  2019
# 2    0.148  0.018537  0.000895  0.048263  2020
# 3    0.077  0.018452  0.001423  0.077134  2021
# 4    0.058  0.018501  0.001609  0.086969  2022

# %%
significant_points = rdf[rdf["p-value"] <= 0.05]
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.plot(rdf["Year"], rdf["Theil"], marker="o", label="Theil", color="blue")
ax1.plot(rdf["Year"], rdf["BG"], marker="s", label="BG", color="green")
ax1.set_xlabel("Year")
ax1.set_ylabel("Theil / BG Value")
ax1.set_title("Time Series of Theil, BG, and BGshare (2015-2022)")
ax2 = ax1.twinx()
ax2.plot(rdf["Year"], rdf["BGshare"], marker="D", label="BGshare", color="orange")
ax2.scatter(
    significant_points["Year"],
    significant_points["BGshare"],
    color="red",
    label="Significant BGshare (p ≤ 0.05)",
    zorder=3,
)

ax2.set_ylabel("BGshare Value")
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
ax1.grid(True)
plt.show()
