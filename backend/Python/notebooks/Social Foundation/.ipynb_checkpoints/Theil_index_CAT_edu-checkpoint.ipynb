# %%
import sys
sys.executable

import numpy as np
import pandas as pd
import geopandas as gpd
from inequality.theil import Theil
import libpysal
import matplotlib.pyplot as plt
import seaborn as sns
import inequality

# %%
import os
os.getcwd()

data_pth = "../../../frontend/data/"

# %%
df = pd.read_json(f"{data_pth}uet.json")
df.head()
# Out:
#            county        2015        2016        2017        2018        2019  \
# 0     Alt Empordà  50876.5593  50726.6026  50420.3636  51168.6837  51387.4274
# 1     Alt Penedès  29488.7782  29985.5723  30374.4899  30098.6478  30594.2746
# 2      Alt Urgell  26513.2882  26786.2955  27551.1677  28385.4777  28484.2940
# 3  Alta Ribagorça  38484.4748  38403.6980  38250.5879  38865.1033  38601.3414
# 4           Anoia  35687.2697  36837.7562  35116.4335  35088.8907  34870.0012
#
#          2020        2021        2022        2023        2024     region
# 0  51476.0966  51583.4546  51860.3032  51666.9085  53418.0634  Catalunya
# 1  30705.5909  30540.8679  31370.6767  31821.7259  32877.5985  Catalunya
# 2  29377.6926  29194.0498  29895.8451  29767.0552  30060.8576   Pyrenees
# 3  38411.8954  37231.2041  37195.8060  36571.0625  36314.2574   Pyrenees
# 4  34706.3362  35058.2224  34697.4229  34881.9419  36561.8896  Catalunya

# %%
gdf = gpd.read_file(f"{data_pth}geometry_counties_all.geojson")

# %%
ax = gdf.plot(edgecolor = "grey")
ax.set_axis_off()

# %%
gdf.head()
# Out:
#            county                                           geometry
# 0        Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 1     Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...
# 2     Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...
# 3      Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...
# 4  Alta Ribagorça  MULTIPOLYGON (((0.8795 42.6314, 0.87967 42.631...

# %%
uet = gdf.merge(df, on="county", how="left")
uet.head()
# Out:
#            county                                           geometry  \
# 0        Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 1     Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...
# 2     Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...
# 3      Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...
# 4  Alta Ribagorça  MULTIPOLYGON (((0.8795 42.6314, 0.87967 42.631...
#
#          2015        2016        2017        2018        2019        2020  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1  50876.5593  50726.6026  50420.3636  51168.6837  51387.4274  51476.0966
# 2  29488.7782  29985.5723  30374.4899  30098.6478  30594.2746  30705.5909
# 3  26513.2882  26786.2955  27551.1677  28385.4777  28484.2940  29377.6926
# 4  38484.4748  38403.6980  38250.5879  38865.1033  38601.3414  38411.8954
#
#          2021        2022        2023        2024     region
# 0         NaN         NaN         NaN         NaN  Catalunya
# 1  51583.4546  51860.3032  51666.9085  53418.0634  Catalunya
# 2  30540.8679  31370.6767  31821.7259  32877.5985  Catalunya
# 3  29194.0498  29895.8451  29767.0552  30060.8576   Pyrenees
# 4  37231.2041  37195.8060  36571.0625  36314.2574   Pyrenees

# %%
ax = uet.plot(
    column="2015", k=5, scheme="Quantiles", edgecolor="grey", legend=True
)
ax.set_axis_off()
ax.set_title("Rural estate tax 2015");

# %%
theil_2015 = inequality.theil.Theil(uet["2015"].dropna())
theil_2015.T
# Out:
# 0.06084233025322343

# %%
inequality.theil.TheilD
# Out:
# inequality.theil.TheilD

# %%
regimes = uet["region"].astype(str)

# %%
ax = uet.plot(column="region", categorical=True, edgecolor="grey")
ax.set_title("Regions")
ax.set_axis_off()

# %%
np.random.seed(12345)
ts = inequality.theil.TheilD(uet["2015"].dropna(), regimes)

# %%
ts.T
# Out:
# 0.06084233025322343

# %%
ts.bg
# Out:
# array([-0.04567936])

# %%
ts.wg
# Out:
# array([0.10652169])

# %%
ts.bg[0] / ts.T
# Out:
# np.float64(-0.7507825642414515)

# %%
np.random.seed(10)

# %%
mask = uet["2015"].notna()

values =uet.loc[mask, "2015"]
regs   = uet.loc[mask, "region"].astype(str)

ts = inequality.theil.TheilDSim(values, regs, permutations=999)

# %%
ts.bg_pvalue
# Out:
# array([0.528])

# %%
kdeplot = sns.kdeplot(ts.bg, fill=False, legend=False)
x_vals = kdeplot.lines[0].get_xdata()
y_vals = kdeplot.lines[0].get_ydata()
plt.fill_between(x_vals, y_vals, where=(x_vals > ts.bg[0]), color="red")
plt.xlabel("Between Regions Inequality 2015");

# %%
years = range(2015, 2024)
np.random.seed(12345)

ts = [inequality.theil.Theil(uet[f"{year}"]).T for year in years]

regimes = uet["region"]
tsd = [
    inequality.theil.TheilDSim(
        uet[f"{year}"].dropna(),
        regimes[uet[f"{year}"].notna()],  
        permutations=999
    )
    for year in years
]
p = np.array([(tsdi.bg_pvalue[0], tsdi.T, tsdi.results[0].bg[0]) for tsdi in tsd])

# %%
rdf = pd.DataFrame(data=p, columns=["p-value", "Theil", "BG"])
rdf["BGshare"] = rdf.BG / rdf.Theil
rdf["Year"] = years

rdf.head()
# Out:
#    p-value     Theil        BG   BGshare  Year
# 0    0.547  0.060842  0.000694  0.011414  2015
# 1    0.461  0.057993  0.000943  0.016260  2016
# 2    0.387  0.053659  0.001267  0.023607  2017
# 3    0.279  0.050866  0.001751  0.034427  2018
# 4    0.262  0.050271  0.001786  0.035527  2019

# %%
significant_points = rdf[rdf["p-value"] <= 0.05]
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.plot(rdf["Year"], rdf["Theil"], marker="o", label="Theil", color="blue")
ax1.plot(rdf["Year"], rdf["BG"], marker="s", label="BG", color="green")
ax1.set_xlabel("Year")
ax1.set_ylabel("Theil / BG Value")
ax1.set_title("Time Series of Theil, BG, and BGshare (2013-2022)")
ax2 = ax1.twinx()
ax2.plot(rdf["Year"], rdf["BGshare"], marker="D", label="BGshare", color="orange")
ax2.scatter(
    significant_points["Year"],
    significant_points["BGshare"],
    color="red",
    label="Significant BGshare (p ≤ 0.05)",
    zorder=3,
)

ax2.set_ylabel("BGshare Value")
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
ax1.grid(True)
plt.show()
