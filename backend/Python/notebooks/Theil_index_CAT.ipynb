# %%
import sys
sys.executable

import numpy as np
import pandas as pd
import geopandas as gpd
from inequality.theil import Theil
import libpysal
import matplotlib.pyplot as plt
import seaborn as sns
import inequality

# %%
import os
os.getcwd()

data_pth = "../../../frontend/data/"

# %%
df = pd.read_json(f"{data_pth}income.json")
df.head()
# Out:
#            county     2015     2016     2017     2018     2019     2020  \
# 0      Alt Urgell  16920.0  17424.0  18098.0  18467.0  19304.0  19139.0
# 1  Alta Ribagorça  18419.0  18839.0  19210.0  19517.0  20158.0  20647.0
# 2            Aran  19732.0  20169.0  20739.0  20646.0  21434.0  20587.0
# 3        Berguedà  17794.0  18442.0  19093.0  19494.0  20585.0      NaN
# 4        Cerdanya  18293.0  19139.0  20156.0  20269.0  21634.0  20635.0
#
#       2021     2022   2023    region
# 0  20488.0  21466.0  22333  Pyrenees
# 1  21778.0  22454.0  22851  Pyrenees
# 2  21495.0  24270.0  24755  Pyrenees
# 3  21350.0  22473.0  22981  Pyrenees
# 4  23070.0  24677.0  25353  Pyrenees

# %%
gdf = gpd.read_file(f"{data_pth}geometry_counties_all.geojson")

# %%
ax = gdf.plot(edgecolor = "grey")
ax.set_axis_off()

# %%
gdf.head()
# Out:
#            county                                           geometry
# 0        Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...
# 1     Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...
# 2     Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...
# 3      Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...
# 4  Alta Ribagorça  MULTIPOLYGON (((0.8795 42.6314, 0.87967 42.631...

# %%
income = gdf.merge(df, on="county", how="left")
income.head()
# Out:
#         county                                           geometry     2015  \
# 0     Alt Camp  MULTIPOLYGON (((1.47594 41.47798, 1.47959 41.4...  19099.0
# 1  Alt Empordà  MULTIPOLYGON (((3.22338 42.23682, 3.22336 42.2...  18797.0
# 2  Alt Penedès  MULTIPOLYGON (((1.6169 41.5126, 1.61712 41.512...  20888.0
# 3   Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...  16920.0
# 4   Alt Urgell  MULTIPOLYGON (((1.31941 41.99157, 1.32141 41.9...  16920.0
#
#       2016     2017     2018     2019     2020     2021     2022   2023  \
# 0  19721.0  20233.0  20638.0  20911.0  20727.0  21809.0  22827.0  23305
# 1  19397.0  19913.0  20155.0  20840.0  20178.0  21943.0  23037.0  23443
# 2  21462.0  22253.0  22703.0  23166.0  23012.0  24163.0  25230.0  25969
# 3  17424.0  18098.0  18467.0  19304.0  19139.0  20488.0  21466.0  22333
# 4  17424.0  18098.0  18467.0  19304.0  19139.0  20488.0  21466.0  22333
#
#       region
# 0  Catalonia
# 1  Catalonia
# 2  Catalonia
# 3   Pyrenees
# 4  Catalonia

# %%
ax = income.plot(
    column="2023", k=5, scheme="Quantiles", edgecolor="grey", legend=True
)
ax.set_axis_off()
ax.set_title("Personal income tax 2023");
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\geopandas\plotting.py:736, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, autolim, **style_kwds)
#     735 try:
# --> 736     import mapclassify
#     738 except ImportError:
#
# ModuleNotFoundError: No module named 'mapclassify'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ax = income.plot(
#       2     column="2023", k=5, scheme="Quantiles", edgecolor="grey", legend=True
#       3 )
#       4 ax.set_axis_off()
#       5 ax.set_title("Personal income tax 2023");
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\geopandas\plotting.py:962, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     960 kind = kwargs.pop("kind", "geo")
#     961 if kind == "geo":
# --> 962     return plot_dataframe(data, *args, **kwargs)
#     963 if kind in self._pandas_kinds:
#     964     # Access pandas plots
#     965     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~\miniforge3\envs\jupyter_clean\Lib\site-packages\geopandas\plotting.py:739, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, autolim, **style_kwds)
#     736     import mapclassify
#     738 except ImportError:
# --> 739     raise ImportError(mc_err)
#     741 if classification_kwds is None:
#     742     classification_kwds = {}
#
# ImportError: The 'mapclassify' package is required to use the 'scheme' keyword.

# %%
theil_2023 = inequality.theil.Theil(income["2023"])
theil_2023.T
# Out:
# 0.006396315123168008

# %%
inequality.theil.TheilD
# Out:
# inequality.theil.TheilD

# %%
regimes = income["region"]

# %%
ax = income.plot(column="region", categorical=True, edgecolor="grey")
ax.set_title("Regions")
ax.set_axis_off()

# %%
np.random.seed(12345)
ts = inequality.theil.TheilD(income["2023"], regimes)

# %%
ts.T
# Out:
# 0.006396315123168008

# %%
ts.bg
# Out:
# array([0.00010388])

# %%
ts.wg
# Out:
# array([0.00629244])

# %%
ts.bg[0] / ts.T
# Out:
# np.float64(0.016240057147185637)

# %%
np.random.seed(10)

# %%
ts = inequality.theil.TheilDSim(income["2023"], regimes, permutations=999)

# %%
ts.bg_pvalue
# Out:
# array([0.387])

# %%
kdeplot = sns.kdeplot(ts.bg, fill=False, legend=False)
x_vals = kdeplot.lines[0].get_xdata()
y_vals = kdeplot.lines[0].get_ydata()
plt.fill_between(x_vals, y_vals, where=(x_vals > ts.bg[0]), color="red")
plt.xlabel("Between Regions Inequality 2023");

# %%
years = range(2015, 2024)
np.random.seed(12345)

ts = [inequality.theil.Theil(income[f"{year}"].dropna()).T for year in years]

regimes = income["region"]
tsd = [
    inequality.theil.TheilDSim(
        income[f"{year}"].dropna(),
        regimes[income[f"{year}"].notna()],  
        permutations=999
    )
    for year in years
]
p = np.array([(tsdi.bg_pvalue[0], tsdi.T, tsdi.results[0].bg[0]) for tsdi in tsd])

# %%
rdf = pd.DataFrame(data=p, columns=["p-value", "Theil", "BG"])
rdf["BGshare"] = rdf.BG / rdf.Theil
rdf["Year"] = years

rdf.head()
# Out:
#    p-value     Theil        BG   BGshare  Year
# 0    0.160  0.008037  0.000298  0.037066  2015
# 1    0.211  0.007898  0.000267  0.033827  2016
# 2    0.151  0.007493  0.000300  0.040044  2017
# 3    0.172  0.007597  0.000296  0.038926  2018
# 4    0.198  0.007629  0.000230  0.030165  2019

# %%
significant_points = rdf[rdf["p-value"] <= 0.05]
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.plot(rdf["Year"], rdf["Theil"], marker="o", label="Theil", color="blue")
ax1.plot(rdf["Year"], rdf["BG"], marker="s", label="BG", color="green")
ax1.set_xlabel("Year")
ax1.set_ylabel("Theil / BG Value")
ax1.set_title("Time Series of Theil, BG, and BGshare (2015-2023)")
ax2 = ax1.twinx()
ax2.plot(rdf["Year"], rdf["BGshare"], marker="D", label="BGshare", color="orange")
ax2.scatter(
    significant_points["Year"],
    significant_points["BGshare"],
    color="red",
    label="Significant BGshare (p ≤ 0.05)",
    zorder=3,
)

ax2.set_ylabel("BGshare Value")
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
ax1.grid(True)
plt.show()
